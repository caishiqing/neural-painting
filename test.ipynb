# %%
from renderer import OilBrush
from matplotlib import pyplot as plt

render = OilBrush()

# %%
render.random_params()
render.draw_stroke()
plt.subplot(1, 2, 1)
plt.imshow(render.foreground)
plt.subplot(1, 2, 2)
plt.imshow(render.canvas)
plt.show()
render.params
# Out:
# array([ 58.56127869, 100.28675099,  89.69596864, 121.11219811,
#          2.21013774,   0.86707338,   0.86405894,   0.89245291,
#          0.89774031,   0.67403914,   0.66132809,   0.85816392])
